# %% [markdown]
# <a href="https://colab.research.google.com/github/tinybeachthor/ucboulder-ml-supervised/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## Load data
#
# https://www.kaggle.com/datasets/sujaykapadnis/top-100-billboard
#
# This dataset contains:
# - Billboard 100 data from 1958 to 2021
# - Spotify audio features for songs

# %%
# !git clone https://github.com/tinybeachthor/ucboulder-ml-supervised
# %cd ucboulder-ml-supervised
# Out:
# Cloning into 'ucboulder-ml-supervised'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10 (delta 0), reused 7 (delta 0), pack-reused 0
# Receiving objects: 100% (10/10), 12.38 MiB | 17.46 MiB/s, done.
# /content/ucboulder-ml-supervised

# %%
# !unzip data/billboard.csv.zip
# !unzip data/audio_features.csv.zip
# Out:
# Archive:  data/billboard.csv.zip
#   inflating: billboard.csv
# Archive:  data/audio_features.csv.zip
#   inflating: audio_features.csv

# %%
billboard = pd.read_csv('billboard.csv')
billboard.head()
# Out:
#                                                  url    week_id  \
# 0  http://www.billboard.com/charts/hot-100/1965-0...  7/17/1965
# 1  http://www.billboard.com/charts/hot-100/1965-0...  7/24/1965
# 2  http://www.billboard.com/charts/hot-100/1965-0...  7/31/1965
# 3  http://www.billboard.com/charts/hot-100/1965-0...   8/7/1965
# 4  http://www.billboard.com/charts/hot-100/1965-0...  8/14/1965
#
#    week_position                    song   performer  \
# 0             34  Don't Just Stand There  Patty Duke
# 1             22  Don't Just Stand There  Patty Duke
# 2             14  Don't Just Stand There  Patty Duke
# 3             10  Don't Just Stand There  Patty Duke
# 4              8  Don't Just Stand There  Patty Duke
#
#                             song_id  instance  previous_week_position  \
# 0  Don't Just Stand TherePatty Duke         1                    45.0
# 1  Don't Just Stand TherePatty Duke         1                    34.0
# 2  Don't Just Stand TherePatty Duke         1                    22.0
# 3  Don't Just Stand TherePatty Duke         1                    14.0
# 4  Don't Just Stand TherePatty Duke         1                    10.0
#
#    peak_position  weeks_on_chart
# 0             34               4
# 1             22               5
# 2             14               6
# 3             10               7
# 4              8               8

# %%
audio_features = pd.read_csv('audio_features.csv')
audio_features.head()
# Out:
#                                              song_id           performer  \
# 0     -twistin'-White Silver SandsBill Black's Combo  Bill Black's Combo
# 1  ¿Dònde Està Santa Claus? (Where Is Santa Claus...          Augie Rios
# 2             ......And Roses And RosesAndy Williams       Andy Williams
# 3           ...And Then There Were DrumsSandy Nelson        Sandy Nelson
# 4                ...Baby One More TimeBritney Spears      Britney Spears
#
#                                                song  \
# 0                      -twistin'-White Silver Sands
# 1  ¿Dònde Està Santa Claus? (Where Is Santa Claus?)
# 2                         ......And Roses And Roses
# 3                      ...And Then There Were Drums
# 4                             ...Baby One More Time
#
#                                        spotify_genre        spotify_track_id  \
# 0                                                 []                     NaN
# 1                                        ['novelty']                     NaN
# 2  ['adult standards', 'brill building pop', 'eas...  3tvqPPpXyIgKrm4PR9HCf0
# 3   ['rock-and-roll', 'space age pop', 'surf music']  1fHHq3qHU8wpRKHzhojZ4a
# 4              ['dance pop', 'pop', 'post-teen pop']  3MjUtNVVq3C8Fn0MP3zhXa
#
#                            spotify_track_preview_url  \
# 0                                                NaN
# 1                                                NaN
# 2  https://p.scdn.co/mp3-preview/cef4883cfd1e0e53...
# 3                                                NaN
# 4  https://p.scdn.co/mp3-preview/da2134a161f1cb34...
#
#    spotify_track_duration_ms spotify_track_explicit  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                   166106.0                  False
# 3                   172066.0                  False
# 4                   211066.0                  False
#
#                               spotify_track_album  danceability  ...  \
# 0                                             NaN           NaN  ...
# 1                                             NaN           NaN  ...
# 2                     The Essential Andy Williams         0.154  ...
# 3                           Compelling Percussion         0.588  ...
# 4  ...Baby One More Time (Digital Deluxe Version)         0.759  ...
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       NaN   NaN          NaN           NaN               NaN       NaN
# 1       NaN   NaN          NaN           NaN               NaN       NaN
# 2   -14.063   1.0       0.0315       0.91100          0.000267     0.112
# 3   -17.278   0.0       0.0361       0.00256          0.745000     0.145
# 4    -5.745   0.0       0.0307       0.20200          0.000131     0.443
#
#    valence    tempo  time_signature  spotify_track_popularity
# 0      NaN      NaN             NaN                       NaN
# 1      NaN      NaN             NaN                       NaN
# 2    0.150   83.969             4.0                      38.0
# 3    0.801  121.962             4.0                      11.0
# 4    0.907   92.960             4.0                      77.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Clean data

# %% [markdown]
# ### Billboard
#
# - Convert `week_id` to datetime
# - Filter data from 2010 to 2020
# - Group into single row per song
# - Construct columns describing songs (first week on chart, last week on chart, highest rank, lowest rank, ...)

# %%
billboard.dtypes
# Out:
# url                        object
# week_id                    object
# week_position               int64
# song                       object
# performer                  object
# song_id                    object
# instance                    int64
# previous_week_position    float64
# peak_position               int64
# weeks_on_chart              int64
# dtype: object

# %%
billboard['week'] = pd.to_datetime(billboard.week_id)

# %%
start_date = datetime(2010, 1, 1)
end_date = datetime(2020, 1, 1)
billboard_2010s = billboard[billboard['week'].between(start_date, end_date)]

# %%
billboard_2010s_min = billboard_2010s.groupby(by=['song_id']).min()
billboard_2010s_max = billboard_2010s.groupby(by=['song_id']).max()

# %%
billboard_clean = pd.DataFrame({
    'song': billboard_2010s_min.song,
    'performer': billboard_2010s_min.performer,

    'first_week_on_chart': billboard_2010s_min.week,
    'last_week_on_chart': billboard_2010s_max.week,
    'weeks_on_chart': billboard_2010s_max.weeks_on_chart,

    'highest_position': billboard_2010s_min.peak_position,
    'lowest_position': billboard_2010s_max.week_position,
}).sort_values(by=['first_week_on_chart'])

billboard_clean.head(10)
# Out:
#                                                              song  \
# song_id
# Sexy ChickDavid Guetta Featuring Akon                  Sexy Chick
# Russian RouletteRihanna                          Russian Roulette
# Give It Up To MeShakira Featuring Lil Wayne      Give It Up To Me
# Say AahTrey Songz Featuring Fabolous                      Say Aah
# Heartbreak WarfareJohn Mayer                   Heartbreak Warfare
# Hell Breaks LooseEminem Featuring Dr. Dre       Hell Breaks Loose
# Kings And QueensThirty Seconds To Mars           Kings And Queens
# Sex TherapyRobin Thicke                               Sex Therapy
# You Belong With MeTaylor Swift                 You Belong With Me
# Empire State Of MindJay-Z + Alicia Keys      Empire State Of Mind
#
#                                                                  performer  \
# song_id
# Sexy ChickDavid Guetta Featuring Akon          David Guetta Featuring Akon
# Russian RouletteRihanna                                            Rihanna
# Give It Up To MeShakira Featuring Lil Wayne    Shakira Featuring Lil Wayne
# Say AahTrey Songz Featuring Fabolous         Trey Songz Featuring Fabolous
# Heartbreak WarfareJohn Mayer                                    John Mayer
# Hell Breaks LooseEminem Featuring Dr. Dre         Eminem Featuring Dr. Dre
# Kings And QueensThirty Seconds To Mars              Thirty Seconds To Mars
# Sex TherapyRobin Thicke                                       Robin Thicke
# You Belong With MeTaylor Swift                                Taylor Swift
# Empire State Of MindJay-Z + Alicia Keys                Jay-Z + Alicia Keys
#
#                                             first_week_on_chart  \
# song_id
# Sexy ChickDavid Guetta Featuring Akon                2010-01-02
# Russian RouletteRihanna                              2010-01-02
# Give It Up To MeShakira Featuring Lil Wayne          2010-01-02
# Say AahTrey Songz Featuring Fabolous                 2010-01-02
# Heartbreak WarfareJohn Mayer                         2010-01-02
# Hell Breaks LooseEminem Featuring Dr. Dre            2010-01-02
# Kings And QueensThirty Seconds To Mars               2010-01-02
# Sex TherapyRobin Thicke                              2010-01-02
# You Belong With MeTaylor Swift                       2010-01-02
# Empire State Of MindJay-Z + Alicia Keys              2010-01-02
#
#                                             last_week_on_chart  \
# song_id
# Sexy ChickDavid Guetta Featuring Akon               2010-05-22
# Russian RouletteRihanna                             2010-02-06
# Give It Up To MeShakira Featuring Lil Wayne         2010-02-06
# Say AahTrey Songz Featuring Fabolous                2010-06-12
# Heartbreak WarfareJohn Mayer                        2010-05-08
# Hell Breaks LooseEminem Featuring Dr. Dre           2010-01-02
# Kings And QueensThirty Seconds To Mars              2010-01-09
# Sex TherapyRobin Thicke                             2010-05-08
# You Belong With MeTaylor Swift                      2010-04-17
# Empire State Of MindJay-Z + Alicia Keys             2010-04-17
#
#                                              weeks_on_chart  highest_position  \
# song_id
# Sexy ChickDavid Guetta Featuring Akon                    40                 5
# Russian RouletteRihanna                                  14                 9
# Give It Up To MeShakira Featuring Lil Wayne              11                29
# Say AahTrey Songz Featuring Fabolous                     29                 9
# Heartbreak WarfareJohn Mayer                             20                34
# Hell Breaks LooseEminem Featuring Dr. Dre                 1                29
# Kings And QueensThirty Seconds To Mars                    5                82
# Sex TherapyRobin Thicke                                  19                54
# You Belong With MeTaylor Swift                           50                 2
# Empire State Of MindJay-Z + Alicia Keys                  30                 1
#
#                                              lowest_position
# song_id
# Sexy ChickDavid Guetta Featuring Akon                     50
# Russian RouletteRihanna                                  100
# Give It Up To MeShakira Featuring Lil Wayne               99
# Say AahTrey Songz Featuring Fabolous                      43
# Heartbreak WarfareJohn Mayer                              93
# Hell Breaks LooseEminem Featuring Dr. Dre                 29
# Kings And QueensThirty Seconds To Mars                   100
# Sex TherapyRobin Thicke                                  100
# You Belong With MeTaylor Swift                            50
# Empire State Of MindJay-Z + Alicia Keys                   47

# %% [markdown]
# ### Audio features
#
# - Drop rows without data (`spotify_track_id` missing)
# - Select interesting columns

# %%
audio_features.index = audio_features['song_id']

# %%
audio_features.columns
# Out:
# Index(['song_id', 'performer', 'song', 'spotify_genre', 'spotify_track_id',
#        'spotify_track_preview_url', 'spotify_track_duration_ms',
#        'spotify_track_explicit', 'spotify_track_album', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'spotify_track_popularity'],
#       dtype='object')

# %%
audio_features_clean = audio_features[audio_features.spotify_track_id.notna()]
audio_features_clean = audio_features_clean.drop(columns=[
    'song_id', 'performer', 'song',
    'spotify_genre',
    'spotify_track_id',
    'spotify_track_preview_url',
    'spotify_track_popularity',
    'spotify_track_album',
])

audio_features_clean.head()
# Out:
#                                                    spotify_track_duration_ms  \
# song_id
# ......And Roses And RosesAndy Williams                              166106.0
# ...And Then There Were DrumsSandy Nelson                            172066.0
# ...Baby One More TimeBritney Spears                                 211066.0
# ...Ready For It?Taylor Swift                                        208186.0
# '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles                   205560.0
#
#                                                   spotify_track_explicit  \
# song_id
# ......And Roses And RosesAndy Williams                             False
# ...And Then There Were DrumsSandy Nelson                           False
# ...Baby One More TimeBritney Spears                                False
# ...Ready For It?Taylor Swift                                       False
# '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles                   True
#
#                                                    danceability  energy   key  \
# song_id
# ......And Roses And RosesAndy Williams                    0.154   0.185   5.0
# ...And Then There Were DrumsSandy Nelson                  0.588   0.672  11.0
# ...Baby One More TimeBritney Spears                       0.759   0.699   0.0
# ...Ready For It?Taylor Swift                              0.613   0.764   2.0
# '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles           NaN     NaN   NaN
#
#                                                    loudness  mode  \
# song_id
# ......And Roses And RosesAndy Williams              -14.063   1.0
# ...And Then There Were DrumsSandy Nelson            -17.278   0.0
# ...Baby One More TimeBritney Spears                  -5.745   0.0
# ...Ready For It?Taylor Swift                         -6.509   1.0
# '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles       NaN   NaN
#
#                                                    speechiness  acousticness  \
# song_id
# ......And Roses And RosesAndy Williams                  0.0315       0.91100
# ...And Then There Were DrumsSandy Nelson                0.0361       0.00256
# ...Baby One More TimeBritney Spears                     0.0307       0.20200
# ...Ready For It?Taylor Swift                            0.1360       0.05270
# '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles          NaN           NaN
#
#                                                    instrumentalness  liveness  \
# song_id
# ......And Roses And RosesAndy Williams                     0.000267     0.112
# ...And Then There Were DrumsSandy Nelson                   0.745000     0.145
# ...Baby One More TimeBritney Spears                        0.000131     0.443
# ...Ready For It?Taylor Swift                               0.000000     0.197
# '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles               NaN       NaN
#
#                                                    valence    tempo  \
# song_id
# ......And Roses And RosesAndy Williams               0.150   83.969
# ...And Then There Were DrumsSandy Nelson             0.801  121.962
# ...Baby One More TimeBritney Spears                  0.907   92.960
# ...Ready For It?Taylor Swift                         0.417  160.015
# '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles      NaN      NaN
#
#                                                    time_signature
# song_id
# ......And Roses And RosesAndy Williams                        4.0
# ...And Then There Were DrumsSandy Nelson                      4.0
# ...Baby One More TimeBritney Spears                           4.0
# ...Ready For It?Taylor Swift                                  4.0
# '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles             NaN

# %% [markdown]
# ### Merge
#
# - Merge into single DataFrame

# %%
df = billboard_clean.merge(audio_features_clean, how='left', left_index=True, right_index=True)
df.head()
# Out:
#                                                                         song  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                           #Beautiful
# #SELFIEThe Chainsmokers                                              #SELFIE
# #thatPOWERwill.i.am Featuring Justin Bieber                       #thatPOWER
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...            $ave Dat Money
# 'Til Summer Comes AroundKeith Urban                 'Til Summer Comes Around
#
#                                                                                           performer  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                               Mariah Carey Featuring Miguel
# #SELFIEThe Chainsmokers                                                            The Chainsmokers
# #thatPOWERwill.i.am Featuring Justin Bieber                       will.i.am Featuring Justin Bieber
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...  Lil Dicky Featuring Fetty Wap & Rich Homie Quan
# 'Til Summer Comes AroundKeith Urban                                                     Keith Urban
#
#                                                    first_week_on_chart  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                     2013-05-25
# #SELFIEThe Chainsmokers                                     2014-03-15
# #thatPOWERwill.i.am Featuring Justin Bieber                 2013-04-06
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...          2015-10-10
# 'Til Summer Comes AroundKeith Urban                         2010-01-30
#
#                                                    last_week_on_chart  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                    2013-09-07
# #SELFIEThe Chainsmokers                                    2014-05-24
# #thatPOWERwill.i.am Featuring Justin Bieber                2013-07-20
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...         2016-03-19
# 'Til Summer Comes AroundKeith Urban                        2010-05-15
#
#                                                     weeks_on_chart  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                         16
# #SELFIEThe Chainsmokers                                         11
# #thatPOWERwill.i.am Featuring Justin Bieber                     16
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...              19
# 'Til Summer Comes AroundKeith Urban                             16
#
#                                                     highest_position  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                           15
# #SELFIEThe Chainsmokers                                           16
# #thatPOWERwill.i.am Featuring Justin Bieber                       17
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...                71
# 'Til Summer Comes AroundKeith Urban                               58
#
#                                                     lowest_position  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                          95
# #SELFIEThe Chainsmokers                                          95
# #thatPOWERwill.i.am Featuring Justin Bieber                      85
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...              100
# 'Til Summer Comes AroundKeith Urban                              94
#
#                                                     spotify_track_duration_ms  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                              199866.0
# #SELFIEThe Chainsmokers                                              183750.0
# #thatPOWERwill.i.am Featuring Justin Bieber                          279506.0
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...                   290835.0
# 'Til Summer Comes AroundKeith Urban                                  331466.0
#
#                                                    spotify_track_explicit  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                             False
# #SELFIEThe Chainsmokers                                             False
# #thatPOWERwill.i.am Featuring Justin Bieber                         False
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...                   True
# 'Til Summer Comes AroundKeith Urban                                 False
#
#                                                     danceability  ...  key  \
# song_id                                                           ...
# #BeautifulMariah Carey Featuring Miguel                    0.677  ...  4.0
# #SELFIEThe Chainsmokers                                    0.807  ...  0.0
# #thatPOWERwill.i.am Featuring Justin Bieber                0.797  ...  6.0
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...         0.858  ...  2.0
# 'Til Summer Comes AroundKeith Urban                        0.570  ...  9.0
#
#                                                     loudness  mode  \
# song_id
# #BeautifulMariah Carey Featuring Miguel               -5.405   1.0
# #SELFIEThe Chainsmokers                               -3.282   1.0
# #thatPOWERwill.i.am Featuring Justin Bieber           -6.096   0.0
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...    -5.361   1.0
# 'Til Summer Comes AroundKeith Urban                   -7.608   0.0
#
#                                                     speechiness  acousticness  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                  0.0391       0.34600
# #SELFIEThe Chainsmokers                                  0.2260       0.01340
# #thatPOWERwill.i.am Featuring Justin Bieber              0.0583       0.00112
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...       0.2300       0.11400
# 'Til Summer Comes AroundKeith Urban                      0.0331       0.59300
#
#                                                     instrumentalness  \
# song_id
# #BeautifulMariah Carey Featuring Miguel                     0.000000
# #SELFIEThe Chainsmokers                                     0.000012
# #thatPOWERwill.i.am Featuring Justin Bieber                 0.000077
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...          0.000000
# 'Til Summer Comes AroundKeith Urban                         0.000136
#
#                                                     liveness  valence  \
# song_id
# #BeautifulMariah Carey Featuring Miguel               0.3470    0.469
# #SELFIEThe Chainsmokers                               0.0787    0.651
# #thatPOWERwill.i.am Featuring Justin Bieber           0.0748    0.403
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...    0.2240    0.364
# 'Til Summer Comes AroundKeith Urban                   0.7700    0.308
#
#                                                       tempo  time_signature
# song_id
# #BeautifulMariah Carey Featuring Miguel             107.042             4.0
# #SELFIEThe Chainsmokers                             127.973             4.0
# #thatPOWERwill.i.am Featuring Justin Bieber         128.000             4.0
# $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...   98.012             4.0
# 'Til Summer Comes AroundKeith Urban                 127.907             4.0
#
# [5 rows x 21 columns]

# %%
df = df.sort_values(by=['first_week_on_chart'])
df.head(10)
# Out:
#                                                                             song  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley  I Wanna Make You Close Your Eyes
# I AmMary J. Blige                                                           I Am
# You Belong With MeTaylor Swift                                You Belong With Me
# ReplayIyaz                                                                Replay
# Cryin' For Me (Wayman's Song)Toby Keith            Cryin' For Me (Wayman's Song)
# Baby By Me50 Cent Featuring Ne-Yo                                     Baby By Me
# Red LightDavid Nail                                                    Red Light
# I Wanna RockSnoop Dogg                                              I Wanna Rock
# Give It Up To MeShakira Featuring Lil Wayne                     Give It Up To Me
# I Will Not BowBreaking Benjamin                                   I Will Not Bow
#
#                                                                   performer  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley               Dierks Bentley
# I AmMary J. Blige                                             Mary J. Blige
# You Belong With MeTaylor Swift                                 Taylor Swift
# ReplayIyaz                                                             Iyaz
# Cryin' For Me (Wayman's Song)Toby Keith                          Toby Keith
# Baby By Me50 Cent Featuring Ne-Yo                   50 Cent Featuring Ne-Yo
# Red LightDavid Nail                                              David Nail
# I Wanna RockSnoop Dogg                                           Snoop Dogg
# Give It Up To MeShakira Featuring Lil Wayne     Shakira Featuring Lil Wayne
# I Will Not BowBreaking Benjamin                           Breaking Benjamin
#
#                                                first_week_on_chart  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley          2010-01-02
# I AmMary J. Blige                                       2010-01-02
# You Belong With MeTaylor Swift                          2010-01-02
# ReplayIyaz                                              2010-01-02
# Cryin' For Me (Wayman's Song)Toby Keith                 2010-01-02
# Baby By Me50 Cent Featuring Ne-Yo                       2010-01-02
# Red LightDavid Nail                                     2010-01-02
# I Wanna RockSnoop Dogg                                  2010-01-02
# Give It Up To MeShakira Featuring Lil Wayne             2010-01-02
# I Will Not BowBreaking Benjamin                         2010-01-02
#
#                                                last_week_on_chart  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley         2010-02-27
# I AmMary J. Blige                                      2010-05-08
# You Belong With MeTaylor Swift                         2010-04-17
# ReplayIyaz                                             2010-04-24
# Cryin' For Me (Wayman's Song)Toby Keith                2010-03-13
# Baby By Me50 Cent Featuring Ne-Yo                      2010-02-06
# Red LightDavid Nail                                    2010-01-23
# I Wanna RockSnoop Dogg                                 2010-04-10
# Give It Up To MeShakira Featuring Lil Wayne            2010-02-06
# I Will Not BowBreaking Benjamin                        2010-01-30
#
#                                                 weeks_on_chart  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley              20
# I AmMary J. Blige                                           20
# You Belong With MeTaylor Swift                              50
# ReplayIyaz                                                  34
# Cryin' For Me (Wayman's Song)Toby Keith                     12
# Baby By Me50 Cent Featuring Ne-Yo                           13
# Red LightDavid Nail                                         16
# I Wanna RockSnoop Dogg                                      15
# Give It Up To MeShakira Featuring Lil Wayne                 11
# I Will Not BowBreaking Benjamin                             20
#
#                                                 highest_position  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley                52
# I AmMary J. Blige                                             55
# You Belong With MeTaylor Swift                                 2
# ReplayIyaz                                                     2
# Cryin' For Me (Wayman's Song)Toby Keith                       73
# Baby By Me50 Cent Featuring Ne-Yo                             28
# Red LightDavid Nail                                           54
# I Wanna RockSnoop Dogg                                        41
# Give It Up To MeShakira Featuring Lil Wayne                   29
# I Will Not BowBreaking Benjamin                               40
#
#                                                 lowest_position  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley               87
# I AmMary J. Blige                                            94
# You Belong With MeTaylor Swift                               50
# ReplayIyaz                                                   46
# Cryin' For Me (Wayman's Song)Toby Keith                      91
# Baby By Me50 Cent Featuring Ne-Yo                            98
# Red LightDavid Nail                                          83
# I Wanna RockSnoop Dogg                                      100
# Give It Up To MeShakira Featuring Lil Wayne                  99
# I Will Not BowBreaking Benjamin                              93
#
#                                                 spotify_track_duration_ms  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley                   239119.0
# I AmMary J. Blige                                                237493.0
# You Belong With MeTaylor Swift                                   231133.0
# ReplayIyaz                                                       182306.0
# Cryin' For Me (Wayman's Song)Toby Keith                          285506.0
# Baby By Me50 Cent Featuring Ne-Yo                                213360.0
# Red LightDavid Nail                                              246333.0
# I Wanna RockSnoop Dogg                                           235986.0
# Give It Up To MeShakira Featuring Lil Wayne                      183573.0
# I Will Not BowBreaking Benjamin                                  216733.0
#
#                                                spotify_track_explicit  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley                  False
# I AmMary J. Blige                                               False
# You Belong With MeTaylor Swift                                  False
# ReplayIyaz                                                      False
# Cryin' For Me (Wayman's Song)Toby Keith                         False
# Baby By Me50 Cent Featuring Ne-Yo                                True
# Red LightDavid Nail                                             False
# I Wanna RockSnoop Dogg                                          False
# Give It Up To MeShakira Featuring Lil Wayne                     False
# I Will Not BowBreaking Benjamin                                 False
#
#                                                 danceability  ...   key  \
# song_id                                                       ...
# I Wanna Make You Close Your EyesDierks Bentley         0.599  ...   1.0
# I AmMary J. Blige                                      0.599  ...  11.0
# You Belong With MeTaylor Swift                         0.687  ...   6.0
# ReplayIyaz                                             0.706  ...   9.0
# Cryin' For Me (Wayman's Song)Toby Keith                0.510  ...   8.0
# Baby By Me50 Cent Featuring Ne-Yo                      0.637  ...   0.0
# Red LightDavid Nail                                    0.386  ...   9.0
# I Wanna RockSnoop Dogg                                 0.521  ...   5.0
# Give It Up To MeShakira Featuring Lil Wayne            0.841  ...   5.0
# I Will Not BowBreaking Benjamin                        0.543  ...   8.0
#
#                                                 loudness  mode  speechiness  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley    -5.745   1.0       0.0232
# I AmMary J. Blige                                 -4.663   0.0       0.0334
# You Belong With MeTaylor Swift                    -4.440   1.0       0.0386
# ReplayIyaz                                        -6.323   1.0       0.0708
# Cryin' For Me (Wayman's Song)Toby Keith           -7.685   0.0       0.0284
# Baby By Me50 Cent Featuring Ne-Yo                 -4.721   0.0       0.0773
# Red LightDavid Nail                               -2.468   1.0       0.0372
# I Wanna RockSnoop Dogg                            -3.238   1.0       0.3180
# Give It Up To MeShakira Featuring Lil Wayne       -6.311   0.0       0.0705
# I Will Not BowBreaking Benjamin                   -3.650   1.0       0.0668
#
#                                                 acousticness  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley      0.104000
# I AmMary J. Blige                                   0.066300
# You Belong With MeTaylor Swift                      0.162000
# ReplayIyaz                                          0.173000
# Cryin' For Me (Wayman's Song)Toby Keith             0.362000
# Baby By Me50 Cent Featuring Ne-Yo                   0.004620
# Red LightDavid Nail                                 0.101000
# I Wanna RockSnoop Dogg                              0.168000
# Give It Up To MeShakira Featuring Lil Wayne         0.443000
# I Will Not BowBreaking Benjamin                     0.000192
#
#                                                 instrumentalness  liveness  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley          0.000048    0.1150
# I AmMary J. Blige                                       0.000000    0.2070
# You Belong With MeTaylor Swift                          0.000013    0.1140
# ReplayIyaz                                              0.000000    0.1680
# Cryin' For Me (Wayman's Song)Toby Keith                 0.001390    0.1120
# Baby By Me50 Cent Featuring Ne-Yo                       0.011600    0.0276
# Red LightDavid Nail                                     0.000011    0.2110
# I Wanna RockSnoop Dogg                                  0.000000    0.2890
# Give It Up To MeShakira Featuring Lil Wayne             0.000000    0.1220
# I Will Not BowBreaking Benjamin                         0.000008    0.3800
#
#                                                 valence    tempo  \
# song_id
# I Wanna Make You Close Your EyesDierks Bentley    0.359   95.979
# I AmMary J. Blige                                 0.576   82.251
# You Belong With MeTaylor Swift                    0.443  129.964
# ReplayIyaz                                        0.195   91.031
# Cryin' For Me (Wayman's Song)Toby Keith           0.261  156.080
# Baby By Me50 Cent Featuring Ne-Yo                 0.345  190.097
# Red LightDavid Nail                               0.428  163.907
# I Wanna RockSnoop Dogg                            0.431  122.852
# Give It Up To MeShakira Featuring Lil Wayne       0.688  115.984
# I Will Not BowBreaking Benjamin                   0.591  107.942
#
#                                                 time_signature
# song_id
# I Wanna Make You Close Your EyesDierks Bentley             4.0
# I AmMary J. Blige                                          4.0
# You Belong With MeTaylor Swift                             4.0
# ReplayIyaz                                                 4.0
# Cryin' For Me (Wayman's Song)Toby Keith                    4.0
# Baby By Me50 Cent Featuring Ne-Yo                          4.0
# Red LightDavid Nail                                        3.0
# I Wanna RockSnoop Dogg                                     5.0
# Give It Up To MeShakira Featuring Lil Wayne                4.0
# I Will Not BowBreaking Benjamin                            4.0
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Export data
#
# Export the cleaned and merged dataset.

# %%
filename = 'billboard_2010s.csv'

df.to_csv(filename)

# %% [markdown]
# Download the data.

# %%
from google.colab import files

files.download(filename)
